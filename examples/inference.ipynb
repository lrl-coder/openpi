# %%
import dataclasses

import jax

from openpi.models import model as _model
from openpi.policies import droid_policy
from openpi.policies import policy_config as _policy_config
from openpi.shared import download
from openpi.training import config as _config
from openpi.training import data_loader as _data_loader
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS

# %%
import os
import shutil

# 将虚拟环境的 bin 目录加入系统环境变量 PATH 的最前面
venv_bin_path = "/root/autodl-tmp/openpi/.venv/bin"
os.environ["PATH"] = f"{venv_bin_path}:{os.environ.get('PATH', '')}"

# 测试一下系统现在能不能找到 gsutil
print("检查 gsutil 位置:", shutil.which("gsutil"))
# Out:
# 检查 gsutil 位置: /root/autodl-tmp/openpi/.venv/bin/gsutil

# %% [markdown]
# # Policy inference
#
# The following example shows how to create a policy from a checkpoint and run inference on a dummy example.

# %%
config = _config.get_config("pi0_fast_droid")
checkpoint_dir = download.maybe_download("gs://openpi-assets/checkpoints/pi0_fast_droid")

# Create a trained policy.
policy = _policy_config.create_trained_policy(config, checkpoint_dir)

# Run inference on a dummy example. This example corresponds to observations produced by the DROID runtime.
example = droid_policy.make_droid_example()
result = policy.infer(example)

# Delete the policy to free up memory.
del policy

print("Actions shape:", result["actions"].shape)
# Out:
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/norm_stats.json...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/assets/droid/norm_stats.json...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/_CHECKPOINT_METADATA...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/_METADATA...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/_sharding...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/d/09f58dc991ac3a5a6369e0ca8dc68dcf...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/manifest.ocdbt...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/c070b1f08beb5b409752260a70b45cdf...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/617ca3068d74e554151a448e5127ea5f...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/21bb9f3eae6e29ecc5ac79942cb831a1...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/603b896b2e39d77f34bace3738090417...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/0cd4ec22f7785c431af05e898a7a9f16...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/manifest.ocdbt...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/f7342189943abb99cb4817e8de3d8fe9...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/c9d0c1ed42052704a98ffe3235dd2e72...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/8c0f01989ce510288c6d1ece98882e5f...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/8c0245fa126e0f2d1ab72a9668b6bfd0...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/e3b018bd60606640bb52ea9cf4fe5034...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/177bb6105e54298e4a3b511f6de54e6e...
# Copying gs://openpi-assets/checkpoints/pi0_fast_droid/params/ocdbt.process_0/d/add13bf361ff8af053bab8cb07f81805...
# \ [20/21 files][ 10.1 GiB/ 10.1 GiB]  99% Done  11.4 MiB/s ETA 00:00:00
#   0%|          | 0.00/4.07M [00:00<?, ?iB/s]
# processor_config.json:   0%|          | 0.00/253 [00:00<?, ?B/s]
# processing_action_tokenizer.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/physical-intelligence/fast:
# - processing_action_tokenizer.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tokenizer_config.json:   0%|          | 0.00/322 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.00 [00:00<?, ?B/s]
# Actions shape: (10, 8)

# %% [markdown]
# # Working with a live model
#
#
# The following example shows how to create a live model from a checkpoint and compute training loss. First, we are going to demonstrate how to do it with fake data.

# %%
config = _config.get_config("pi0_aloha_sim")

checkpoint_dir = download.maybe_download("gs://openpi-assets/checkpoints/pi0_aloha_sim")
key = jax.random.key(0)

# Create a model from the checkpoint.
model = config.model.load(_model.restore_params(checkpoint_dir / "params"))

# We can create fake observations and actions to test the model.
obs, act = config.model.fake_obs(), config.model.fake_act()

# Sample actions from the model.
loss = model.compute_loss(key, obs, act)
print("Loss shape:", loss.shape)

# %% [markdown]
# Now, we are going to create a data loader and use a real batch of training data to compute the loss.

# %%
# Reduce the batch size to reduce memory usage.
config = dataclasses.replace(config, batch_size=2)

# Load a single batch of data. This is the same data that will be used during training.
# NOTE: In order to make this example self-contained, we are skipping the normalization step
# since it requires the normalization statistics to be generated using `compute_norm_stats`.
loader = _data_loader.create_data_loader(config, num_batches=1, skip_norm_stats=True)
obs, act = next(iter(loader))

# Sample actions from the model.
loss = model.compute_loss(key, obs, act)

# Delete the model to free up memory.
del model

print("Loss shape:", loss.shape)
